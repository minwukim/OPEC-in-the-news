# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR

# %% [markdown]
# # 1. Execute VAR

# %% [markdown]
# ### 1.1. Load data

# %%
df_newspaper_index = pd.read_csv("database/newspaper_index.csv")
df_realized_volatility = pd.read_csv("database/realized_volatility.csv")

# %% [markdown]
# #### Note that:
# - df_newspaper_index ranges from **1991-04 to 2023-10**
# - df_realized_volatility ranges from **1986-01 to 2023-08**

# %% [markdown]
# ### 1.2. Create a combined dataframe *df_var*

# %%
# Merge the two dataframes on the "month" column
df_var = pd.merge(df_newspaper_index, df_realized_volatility, on="month", how="inner", suffixes=('_newspaper', '_volatility'))

# Rename the columns to match your requirements
df_var.rename(columns={'value_newspaper': 'newspaper_index', 'value_volatility': 'realized_volatility'}, inplace=True)

# Since you want the months starting from 1991-04 to 2023-10, you may need to filter the dataframe
df_var = df_var[(df_var['month'] >= '1991-04') & (df_var['month'] <= '2023-10')]

# Reset the index of the dataframe
df_var.reset_index(drop=True, inplace=True)

# Now df_var should have the columns "month", "newspaper_index", and "realized_volatility" as desired

df_var
# Out:
#        month  newspaper_index  realized_volatility
# 0    1991-04        32.740904            26.416435
# 1    1991-05        33.814744            20.218068
# 2    1991-06        54.761893            17.695459
# 3    1991-07        47.457754            19.773372
# 4    1991-08        36.631362            27.700901
# ..       ...              ...                  ...
# 384  2023-04        94.000128            34.055352
# 385  2023-05        36.450292            39.179082
# 386  2023-06        78.708933            37.050846
# 387  2023-07        29.934583            24.476116
# 388  2023-08        53.256871            22.791945
#
# [389 rows x 3 columns]

# %% [markdown]
# ### 1.3. Conduct VAR (4 lags)

# %%
# Convert "month" to datetime and set as index
df_var['month'] = pd.to_datetime(df_var['month'])
df_var.set_index('month', inplace=True)

# Select only the columns for VAR
df_var_for_analysis = df_var[['newspaper_index', 'realized_volatility']]

# Fit the VAR model with 4 lags
model = VAR(df_var_for_analysis)
results = model.fit(4)

# Summary of the model
print(results.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 05, Nov, 2023
# Time:                     20:20:41
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    17.4072
# Nobs:                     385.000    HQIC:                   17.2957
# Log likelihood:          -4389.89    FPE:                3.01706e+07
# AIC:                      17.2224    Det(Omega_mle):     2.88080e+07
# --------------------------------------------------------------------
# Results for equation newspaper_index
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                         40.809881         7.952645            5.132           0.000
# L1.newspaper_index             0.361217         0.051865            6.965           0.000
# L1.realized_volatility        -0.072458         0.064945           -1.116           0.265
# L2.newspaper_index             0.038535         0.054453            0.708           0.479
# L2.realized_volatility        -0.025620         0.066522           -0.385           0.700
# L3.newspaper_index             0.175011         0.054480            3.212           0.001
# L3.realized_volatility        -0.047236         0.066514           -0.710           0.478
# L4.newspaper_index             0.096972         0.052182            1.858           0.063
# L4.realized_volatility        -0.058293         0.064918           -0.898           0.369
# =========================================================================================
#
# Results for equation realized_volatility
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                         23.502781         6.383003            3.682           0.000
# L1.newspaper_index             0.078397         0.041628            1.883           0.060
# L1.realized_volatility         0.205663         0.052126            3.945           0.000
# L2.newspaper_index            -0.023870         0.043705           -0.546           0.585
# L2.realized_volatility        -0.006217         0.053392           -0.116           0.907
# L3.newspaper_index             0.020131         0.043727            0.460           0.645
# L3.realized_volatility        -0.003097         0.053386           -0.058           0.954
# L4.newspaper_index            -0.003183         0.041882           -0.076           0.939
# L4.realized_volatility        -0.006676         0.052105           -0.128           0.898
# =========================================================================================
#
# Correlation matrix of residuals
#                        newspaper_index  realized_volatility
# newspaper_index               1.000000             0.146799
# realized_volatility           0.146799             1.000000
# /Users/minwukim/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ### 1.4. Conduct AIC test

# %%
# Select only the columns for VAR
df_var_for_analysis = df_var[['newspaper_index', 'realized_volatility']]

# Initialize the VAR model
model = VAR(df_var_for_analysis)

# Select the optimal lag order with AIC
lag_order_results = model.select_order(maxlags=15)
print(lag_order_results.summary())

# The optimal number of lags based on AIC
optimal_lags = lag_order_results.aic

# Fit the VAR model with the optimal number of lags
results = model.fit(optimal_lags)

# Summary of the model with the optimal lags
print(results.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        17.54       17.56   4.159e+07       17.55
# 1        17.28      17.34*   3.186e+07      17.30*
# 2        17.28       17.39   3.201e+07       17.32
# 3       17.26*       17.41  3.135e+07*       17.32
# 4        17.27       17.46   3.169e+07       17.35
# 5        17.29       17.52   3.214e+07       17.38
# 6        17.27       17.54   3.161e+07       17.38
# 7        17.28       17.60   3.200e+07       17.41
# 8        17.30       17.66   3.268e+07       17.44
# 9        17.32       17.72   3.330e+07       17.48
# 10       17.34       17.78   3.390e+07       17.51
# 11       17.36       17.84   3.461e+07       17.55
# 12       17.35       17.88   3.443e+07       17.56
# 13       17.37       17.94   3.505e+07       17.60
# 14       17.37       17.98   3.507e+07       17.61
# 15       17.39       18.04   3.559e+07       17.65
# --------------------------------------------------
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 05, Nov, 2023
# Time:                     20:20:41
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    17.3503
# Nobs:                     386.000    HQIC:                   17.2637
# Log likelihood:          -4402.33    FPE:                2.97038e+07
# AIC:                      17.2068    Det(Omega_mle):     2.86550e+07
# --------------------------------------------------------------------
# Results for equation newspaper_index
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                         42.471424         7.552062            5.624           0.000
# L1.newspaper_index             0.381236         0.050806            7.504           0.000
# L1.realized_volatility        -0.073129         0.065014           -1.125           0.261
# L2.newspaper_index             0.042636         0.054457            0.783           0.434
# L2.realized_volatility        -0.028191         0.066573           -0.423           0.672
# L3.newspaper_index             0.211100         0.051080            4.133           0.000
# L3.realized_volatility        -0.049774         0.064939           -0.766           0.443
# =========================================================================================
#
# Results for equation realized_volatility
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                         23.122943         6.031116            3.834           0.000
# L1.newspaper_index             0.077797         0.040574            1.917           0.055
# L1.realized_volatility         0.205767         0.051920            3.963           0.000
# L2.newspaper_index            -0.023953         0.043490           -0.551           0.582
# L2.realized_volatility        -0.006012         0.053166           -0.113           0.910
# L3.newspaper_index             0.019190         0.040793            0.470           0.638
# L3.realized_volatility        -0.004926         0.051861           -0.095           0.924
# =========================================================================================
#
# Correlation matrix of residuals
#                        newspaper_index  realized_volatility
# newspaper_index               1.000000             0.146000
# realized_volatility           0.146000             1.000000
# /Users/minwukim/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# Fit the VAR model with 4 lags
model = VAR(df_var[['newspaper_index', 'realized_volatility']])
results = model.fit(4)

# Obtain the standard deviation of the residuals for the 'newspaper_index'
std_newspaper_index = results.resid['newspaper_index'].std()

# Construct the impulse vector for a one-standard deviation shock to 'newspaper_index'
# The impulse vector should have the same length as the number of variables in the VAR model
# and a one-standard deviation shock to 'newspaper_index' in the corresponding position
impulse_vector = np.zeros(len(results.params))
# Assuming 'newspaper_index' is the first variable in the VAR model
impulse_vector[0] = std_newspaper_index

# Compute the impulse response function
irf = results.irf(periods=10)  # You can specify the number of periods you want to trace

# Plot the impulse response of 'newspaper_index' to the shock
irf.plot(orth=False)  # Set orth=False for generalized IRF
plt.show()

# To plot the response of 'realized_volatility' to the shock in 'newspaper_index' specifically:
# Get the response of all variables to the shock in 'newspaper_index'
irf_response = irf.impulse_responses(impulse_vector, orthogonalized=False)
# Plot the response of 'realized_volatility' to the shock in 'newspaper_index'
plt.plot(irf_response[:, 1])  # Assuming 'realized_volatility' is the second variable
plt.title('Response of Realized Volatility to a One-SD Shock in Newspaper Index')
plt.xlabel('Periods')
plt.ylabel('Response')
plt.show()
# Out:
# /Users/minwukim/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 24
#      20 plt.show()
#      22 # To plot the response of 'realized_volatility' to the shock in 'newspaper_index' specifically:
#      23 # Get the response of all variables to the shock in 'newspaper_index'
# ---> 24 irf_response = irf.impulse_responses(impulse_vector, orthogonalized=False)
#      25 # Plot the response of 'realized_volatility' to the shock in 'newspaper_index'
#      26 plt.plot(irf_response[:, 1])  # Assuming 'realized_volatility' is the second variable
#
# AttributeError: 'IRAnalysis' object has no attribute 'impulse_responses'
